# %%
s = "AAABBCCDDAAAsseeeqqq"

# %%
oldchar = ""
clist = []
count = 0

for index,char in enumerate(s):
    
    if oldchar == "":
        count += 1
        clist.append(char)
        oldchar = char
    elif char == oldchar:
        count +=1
        if index == len(s)-1:
            clist.append(count)
    elif char != oldchar:
        clist.append(count)
        count = 0
        clist.append(char)
        count += 1
        oldchar = char
        if index == len(s)-1:
            clist.append(count)

clist
# Out:
# ['A', 3, 'B', 2, 'C', 2, 'D', 2, 'A', 3, 's', 2, 'e', 3, 'q', 3]

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url = "https://www.linkedin.com/in/kratika-jain-68822b52"
word = "Mozilla/5.0 (Windows NT 6.3; W…) Gecko/20100101 Firefox/64.0".encode("utf-8")
headers = {"User-Agent":word}

response = requests.get(url,headers = headers)
soup = BeautifulSoup(response.content,"html.parser")
print(soup)
# Out:
# <html><head>
# <script type="text/javascript">
# window.onload = function() {
#   // Parse the tracking code from cookies.
#   var trk = "bf";
#   var trkInfo = "bf";
#   var cookies = document.cookie.split("; ");
#   for (var i = 0; i < cookies.length; ++i) {
#     if ((cookies[i].indexOf("trkCode=") == 0) && (cookies[i].length > 8)) {
#       trk = cookies[i].substring(8);
#     }
#     else if ((cookies[i].indexOf("trkInfo=") == 0) && (cookies[i].length > 8)) {
#       trkInfo = cookies[i].substring(8);
#     }
#   }
#
#   if (window.location.protocol == "http:") {
#     // If "sl" cookie is set, redirect to https.
#     for (var i = 0; i < cookies.length; ++i) {
#       if ((cookies[i].indexOf("sl=") == 0) && (cookies[i].length > 3)) {
#         window.location.href = "https:" + window.location.href.substring(window.location.protocol.length);
#         return;
#       }
#     }
#   }
#
#   // Get the new domain. For international domains such as
# ...

# %%
name = soup.find("h1",attrs={"class":"pv-top-card-section__name inline t-24 t-black t-normal"})
print(name)
# Out:
# None

# %%
import requests
from bs4 import BeautifulSoup

client = requests.Session()

HOMEPAGE_URL = 'https://www.linkedin.com'
LOGIN_URL = 'https://www.linkedin.com/uas/login-submit'

html = client.get(HOMEPAGE_URL).content
soup = BeautifulSoup(html, "html.parser")
csrf = soup.find("login-callout",attrs = {id:"loginCsrfParam-login"})

print (csrf)

login_information = {
    'session_key':'achintj@gmail.com',
    'session_password':'@chint2505232',
    'loginCsrfParam': csrf,
}

client.post(LOGIN_URL, data=login_information)

response = client.get(url,headers = headers)
soup = BeautifulSoup(response.content,"html.parser")

name = soup.find("h1",attrs={"class":"pv-top-card-section__name inline t-24 t-black t-normal"})
print(name)
# Out:
# None
# None

# %%
import http.cookiejar as cookielib
import os
import urllib
import re
import string
from bs4 import BeautifulSoup

username = "achintj@gmail.com"
password = "@chint2505232"

cookie_filename = "parser.cookies.txt"

class LinkedInParser(object):

    def __init__(self, login, password):
        """ Start up... """
        self.login = login
        self.password = password

        # Simulate browser with cookies enabled
        self.cj = cookielib.MozillaCookieJar(cookie_filename)
        if os.access(cookie_filename, os.F_OK):
            self.cj.load()
        self.opener = urllib.request.build_opener(
            urllib.request.HTTPRedirectHandler(),
            urllib.request.HTTPHandler(debuglevel=0),
            urllib.request.HTTPSHandler(debuglevel=0),
            urllib.request.HTTPCookieProcessor(self.cj)
        )
        self.opener.addheaders = [
            ('User-agent', ('Mozilla/4.0 (compatible; MSIE 6.0; '
                           'Windows NT 5.2; .NET CLR 1.1.4322)'))
        ]

        # Login
        self.loginPage()

        title = self.loadTitle()
        print(title)

        self.cj.save()


    def loadPage(self, url, data=None):
        """
        Utility function to load HTML from URLs for us with hack to continue despite 404
        """
#         We'll print the url in case of infinite loop
        print ("Loading URL: %s" % url)
        try:
            if data is not None:
                response = self.opener.open(url, data)
            else:
                response = self.opener.open(url)
            return ''.join([str(l) for l in response.readlines()])
        except Exception as e:
            # If URL doesn't load for ANY reason, try again...
            # Quick and dirty solution for 404 returns because of network problems
            # However, this could infinite loop if there's an actual problem
            return self.loadPage(url, data)

    def loadSoup(self, url, data=None):
        """
        Combine loading of URL, HTML, and parsing with BeautifulSoup
        """
        html = self.loadPage(url, data)
        print(url)
        soup = BeautifulSoup(html, "html5lib")
        print(url)
        print("load soup")
        return soup

    def loginPage(self):
        """
        Handle login. This should populate our cookie jar.
        """
        soup = self.loadSoup("https://www.linkedin.com/")
        csrf = soup.find(id="loginCsrfParam-login")
        login_data = urllib.parse.urlencode({
            'session_key': self.login,
            'session_password': self.password,
            'loginCsrfParam': csrf,
        }).encode('utf8')

        self.loadPage("https://www.linkedin.com/uas/login-submit", login_data)
        print("login")
        return

    def loadTitle(self):
        print("load title1")
        soup = self.loadSoup("https://www.linkedin.com/in/kratika-jain-68822b52/")
        print("load title2")
        return soup.find("h1", attrs={"class": "pv-top-card-section__name inline t-24 t-black t-normal"})

parser = LinkedInParser(username, password)
# Out:
# Loading URL: https://www.linkedin.com/
# https://www.linkedin.com/
# https://www.linkedin.com/
# load soup
# Loading URL: https://www.linkedin.com/uas/login-submit
# login
# load title1
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# Loading URL: https://www.linkedin.com/in/kratika-jain-68822b52/
# ...
